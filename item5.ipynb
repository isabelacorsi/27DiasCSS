# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelacorsi/30DiasCSS/blob/main/item5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install -U scikit-learn

# %%
import pandas as pd
from sklearn.naive_bayes import MultinomialNB #biblioteca para o classificador
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
#importação  e manipulação dos dados
data = pd.read_excel("NLP.xlsx")

artista = data.iloc[:,1] #armazena a ultima coluna
letra = data.iloc[:,0] #armazena a primeira coluna, a plicaa função "textclean"

# %%
# inicializa o CountVectorizer e o fit aplica o vetorizado nos dados
transform = CountVectorizer(analyzer=textclean).fit(data['letra'])
transform.vocabulary_ #imprime o vocabulário
# Out:
# {'Jayz': 1311,
#  'Uhuhuh': 2666,
#  'ready': 7549,
#  'b': 3227,
#  'Lets': 1468,
#  'go': 5393,
#  'get': 5342,
#  'em': 4756,
#  'Look': 1515,
#  'young': 9636,
#  'Cruisin': 600,
#  'west': 9422,
#  'side': 8114,
#  'highway': 5663,
#  'Doin': 715,
#  'like': 6246,
#  'way': 9385,
#  'Eyes': 861,
#  'behind': 3367,
#  'shades': 8020,
#  'necklace': 6778,
#  'reason': 7564,
#  'dates': 4344,
#  'blind': 3471,
#  'today': 8937,
#  'Ive': 1278,
#  'got': 5424,
#  'thoroughest': 8862,
#  'girl': 5360,
#  'Im': 1242,
#  'mashin': 6457,
#  'gas': 5320,
#  'shes': 8051,
#  'grabbin': 5432,
#  'wheel': 9438,
#  'true': 9058,
#  'heart': 5610,
#  'rides': 7725,
#  'wit': 9520,
#  'new': 6796,
#  'bobby': 3501,
#  'whitney': 9462,
#  'time': 8915,
#  'dont': 4586,
#  'speak': 8357,
#  'durin': 4691,
#  'sex': 8008,
#  'city': 3922,
#  'gets': 5343,
#  'carrie': 3759,
#  'feva': 5046,
#  'soon': 8324,
#  'shows': 8102,
#  'ova': 6967,
#  'Shes': 2260,
#  'right': 7731,
#  'back': 3236,
#  'souljah': 8334,
#  'Cuz': 618,
#  'mamis': 6427,
#  'rida': 7720,
#  'rolla': 7777,
#  'Put': 2008,
#  'us': 9188,
#  'togetha': 8942,
#  'gon': 5407,
#  'stop': 8492,
#  'Whateva': 2781,
#  'lacks': 6108,
#  'shoulder': 8091,
#  'track': 8995,
#  'mami': 6425,
#  'keepin': 6031,
#  'focused': 5167,
#  'lets': 6202,
#  'lock': 6296,
#  'supposed': 8626,
#  '03': 1,
#  'bonnie': 3520,
#  'clyde': 3975,
#  'hov': 5758,
#  'Holla': 1178,
#  'Chorus': 509,
#  'need': 6780,
#  'life': 6230,
#  'sin': 8142,
#  'girlfriend': 5361,
#  'ride': 7722,
#  'till': 8913,
#  'end': 4780,
#  'boyfriend': 3569,
#  'problem': 7364,
#  'dudes': 4681,
#  'treat': 9019,
#  'one': 6911,
#  'lovin': 6357,
#  'Wit': 2821,
#  'respect': 7682,
#  'humpin': 5781,
#  'aint': 3017,
#  'nothin': 6844,
#  'eva': 4862,
#  'mad': 6397,
#  'somethin': 8311,
#  'wont': 9536,
#  'oh': 6889,
#  'places': 7195,
#  'comfy': 4018,
#  'beatch': 3328,
#  'Oh': 1812,
#  'see': 7952,
#  'perfect': 7113,
#  'nobody': 6825,
#  'walkin': 9323,
#  'earths': 4716,
#  'surfaces': 8632,
#  'work': 9547,
#  'kid': 6043,
#  'keep': 6029,
#  'workin': 9549,
#  'hermes': 5646,
#  'birkin': 3428,
#  'bag': 3253,
#  'Manolo': 1586,
#  'blahnik': 3452,
#  'timbsaviator': 8914,
#  'lens': 6191,
#  '600': 53,
#  'drops': 4659,
#  'mercedes': 6529,
#  'benz': 3390,
#  'wear': 9394,
#  'burberry': 3653,
#  'swim': 8681,
#  'worry': 9556,
#  'anything': 3108,
#  'necessary': 6776,
#  'let': 6198,
#  'occur': 6879,
#  'yep': 9623,
#  'Chours': 511,
#  'Talk': 2505,
#  'Beyonce': 288,
#  'Id': 1233,
#  'somebody': 8302,
#  'hurts': 5801,
#  'Even': 836,
#  'yaahee': 9594,
#  'Sometimes': 2366,
#  'trip': 9042,
#  'happy': 5564,
#  'could': 4156,
#  'put': 7437,
#  'Nobody': 1771,
#  'nothing': 6845,
#  'ever': 4866,
#  'come': 4012,
#  'promise': 7378,
#  'Ill': 1239,
#  'give': 5366,
#  'love': 6345,
#  'trust': 9063,
#  'One': 1839,
#  'air': 3019,
#  'breathe': 3595,
#  'believe': 3373,
#  'boyfirend': 3568,
#  'challengers': 3826,
#  'group': 5483,
#  'Houston': 1204,
#  'Welcome': 2770,
#  'Lativia': 1435,
#  'Nina': 1765,
#  'Nicky': 1759,
#  'Kelly': 1375,
#  'Ashley': 188,
#  'HipHop': 1168,
#  'Rappin': 2040,
#  'Girls': 1025,
#  'Tyme': 2656,
#  'Htown': 1211,
#  'coming': 4020,
#  'dripping': 4651,
#  'candy': 3725,
#  'ground': 5482,
#  'H': 1091,
#  'town': 8993,
#  'Coming': 548,
#  'know': 6091,
#  'little': 6280,
#  'girls': 5363,
#  'dreamt': 4633,
#  'world': 9552,
#  'Dont': 724,
#  'forget': 5201,
#  'Respect': 2074,
#  'bow': 3564,
#  'bitches': 3437,
#  'took': 8960,
#  'live': 6281,
#  'think': 8850,
#  'wife': 9481,
#  'twisted': 9108,
#  'shit': 8065,
#  'Bow': 353,
#  'Crown': 598,
#  'Town': 2607,
#  'crown': 4249,
#  'drippin': 4650,
#  'Drippin': 747,
#  'Chimamanda': 506,
#  'Ngozi': 1755,
#  'Adichie': 105,
#  'teach': 8759,
#  'shrink': 8103,
#  'make': 6414,
#  'smaller': 8234,
#  'say': 7895,
#  'ambition': 3071,
#  'much': 6694,
#  'aim': 3013,
#  'successful': 8578,
#  'Otherwise': 1861,
#  'threaten': 8869,
#  'man': 6429,
#  'female': 5036,
#  'expected': 4908,
#  'aspire': 3173,
#  'marriage': 6448,
#  'choices': 3894,
#  'Always': 146,
#  'keeping': 6032,
#  'mind': 6578,
#  'Marriage': 1598,
#  'important': 5854,
#  'source': 8339,
#  'Joy': 1337,
#  'mutual': 6724,
#  'support': 8624,
#  'boys': 3571,
#  'raise': 7517,
#  'competitors': 4043,
#  'jobs': 5996,
#  'accomplishments': 2935,
#  'good': 5412,
#  'thing': 8848,
#  'attention': 3190,
#  'men': 6519,
#  'cannot': 3728,
#  'sexual': 8013,
#  'beings': 3370,
#  'Feminist': 896,
#  'person': 7125,
#  'believes': 3376,
#  'social': 8279,
#  'Political': 1947,
#  'economic': 4728,
#  'equality': 4821,
#  'sexes': 8010,
#  'wake': 9318,
#  'flawless': 5125,
#  'Post': 1957,
#  'Ride': 2089,
#  'round': 7799,
#  'Flossin': 930,
#  'diamond': 4482,
#  'rock': 7762,
#  'Roc': 2112,
#  'woke': 9525,
#  'ladies': 6112,
#  'tell': 8779,
#  'Say': 2185,
#  'look': 6315,
#  'tonight': 8955,
#  'God': 1039,
#  'damn': 4319,
#  'Momma': 1683,
#  'taught': 8751,
#  'home': 5698,
#  'training': 9003,
#  'Daddy': 625,
#  'hater': 5579,
#  'sister': 8167,
#  'made': 6398,
#  'feel': 5025,
#  'fine': 5078,
#  'Judges': 1341,
#  'champion': 3829,
#  'Skeleton': 2317,
#  'Groove': 1073,
#  '4': 36,
#  'Stars': 2422,
#  'score': 7917,
#  'challenger': 3825,
#  'receives': 7576,
#  '3': 28,
#  'stars': 8440,
#  'champions': 3830,
#  'Congratulations': 554,
#  'well': 9416,
#  'next': 6799,
#  'week': 9407,
#  'Dumdadeda': 764,
#  'stay': 8454,
#  'Yoncé': 2888,
#  'lingerie': 6265,
#  'chardonnay': 3841,
#  'scorin': 7918,
#  'touchdowns': 8976,
#  'runway': 7830,
#  'Texas': 2535,
#  'forever': 5197,
#  'Bun': 401,
#  'B': 212,
#  'redboned': 7589,
#  'yo': 9628,
#  'really': 7559,
#  'rit': 7750,
#  'Donjae': 722,
#  'camo': 3716,
#  'thots': 8863,
#  'cant': 3730,
#  'clock': 3953,
#  'nowadays': 6850,
#  'wish': 9514,
#  'pound': 7292,
#  'cake': 3699,
#  'Boy': 354,
#  'fuck': 5275,
#  'babymomma': 3233,
#  'Want': 2747,
#  'around': 3151,
#  'karma': 6028,
#  'escalate': 4832,
#  'bitch': 3436,
#  'elevators': 4748,
#  'course': 4175,
#  'sometimes': 8315,
#  'billion': 3423,
#  'dollars': 4575,
#  'elevator': 4747,
#  'Ha': 1100,
#  'ha': 5519,
#  'haters': 5580,
#  'Ridin': 2091,
#  'looking': 6319,
#  'wouldnt': 9569,
#  'change': 3833,
#  'want': 9336,
#  'everyone': 4874,
#  'Onika': 1840,
#  'Looking': 1519,
#  'Trinidadian': 2615,
#  'Japanese': 1306,
#  'Indian': 1257,
#  'Got': 1056,
#  'Malaysian': 1574,
#  'yaki': 9597,
#  'wavy': 9383,
#  'Brazilian': 363,
#  'thirsty': 8856,
#  'Hungarian': 1217,
#  'Nicki': 1758,
#  'eatin': 4723,
#  'fangs': 4980,
#  'barbarian': 3290,
#  'ah': 2999,
#  'Yo': 2885,
#  'MJ': 1553,
#  'doctor': 4565,
#  'killing': 6052,
#  'Propofol': 1985,
#  'hope': 5725,
#  'fall': 4966,
#  'winning': 9506,
#  'motherfuckin': 6670,
#  'protocol': 7391,
#  'Cause': 464,
#  'throw': 8881,
#  'ball': 3269,
#  'washed': 9355,
#  'fuckin': 5277,
#  'soap': 8272,
#  'involved': 5936,
#  'every': 4869,
#  'hood': 5719,
#  'nigga': 6813,
#  'dream': 4627,
#  'fantasizing': 4984,
#  'Curvalicious': 614,
#  'pussy': 7436,
#  'served': 7992,
#  'delicious': 4405,
#  'Mayday': 1613,
#  'mayday': 6485,
#  'earth': 4714,
#  'Slap': 2322,
#  'hoes': 5681,
#  'ass': 3174,
#  'birthing': 3432,
#  'uh': 9121,
#  'queen': 7457,
#  'rap': 7525,
#  'slayin': 8205,
#  'Queen': 2018,
#  'team': 8763,
#  'playin': 7212,
#  'Alisters': 133,
#  'paid': 6995,
#  'sisters': 8168,
#  'watch': 9365,
#  'done': 4585,
#  'phased': 7141,
#  'blizzards': 3479,
#  'confess': 4070,
#  'drank': 4620,
#  'cup': 4281,
#  'dick': 4486,
#  'Instagram': 1262,
#  'another': 3096,
#  'pic': 7156,
#  'Flawless': 921,
#  'titties': 8934,
#  'hundreds': 5784,
#  'fifties': 5053,
#  'cause': 3787,
#  'mobbin': 6624,
#  'pretty': 7339,
#  'niggas': 6814,
#  'bad': 3246,
#  'grizzly': 5477,
#  'Throw': 2564,
#  'frisbee': 5262,
#  'Princess': 1979,
#  'cut': 4297,
#  'diamonds': 4483,
#  'Disney': 704,
#  'monster': 6648,
#  'Sri': 2411,
#  'Lanka': 1427,
#  'told': 8946,
#  'meet': 6500,
#  'Trump': 2624,
#  'Ivanka': 1277,
#  'said': 7851,
#  'show': 8098,
#  'cookie': 4125,
#  'tastes': 8748,
#  'yeah': 9609,
#  'eat': 4722,
#  'face': 4938,
#  'Right': 2094,
#  'something': 8312,
#  'algebra': 3033,
#  '1': 3,
#  'plus': 7232,
#  'equals': 4822,
#  '2': 17,
#  'Thats': 2540,
#  'baby': 3230,
#  'without': 9522,
#  'Darling': 640,
#  'enough': 4798,
#  'days': 4355,
#  'low': 6359,
#  'Pull': 1998,
#  'close': 3956,
#  'Make': 1570,
#  'war': 9342,
#  'Let': 1466,
#  'heal': 5601,
#  'Hey': 1159,
#  'guns': 5508,
#  'shot': 8087,
#  'die': 4489,
#  'fighting': 5060,
#  'fight': 5057,
#  'balled': 3270,
#  'fists': 5098,
#  'realized': 7558,
#  'laying': 6153,
#  'Baby': 224,
#  'darling': 4337,
#  'Help': 1150,
#  'guard': 5494,
#  'Six': 2311,
#  'inch': 5864,
#  'heels': 5627,
#  'walked': 9321,
#  'club': 3968,
#  'nobodys': 6826,
#  'business': 3668,
#  'Goddamn': 1040,
#  'murdered': 6710,
#  'everybody': 4870,
#  'witness': 9523,
#  'stacking': 8421,
#  'money': 6645,
#  'everywhere': 4880,
#  'goes': 5399,
#  'pesos': 7132,
#  'Mexico': 1634,
#  'De': 649,
#  'uno': 9167,
#  'commas': 4023,
#  'decimals': 4377,
#  'gotta': 5426,
#  'professional': 7369,
#  'mixing': 6615,
#  'Ace': 99,
#  'Hennessy': 1153,
#  'thats': 8823,
#  'recipe': 7579,
#  'Rushing': 2147,
#  'veins': 9215,
#  'ecstasy': 4730,
#  'already': 3052,
#  'shell': 8048,
#  'never': 6795,
#  'leave': 6174,
#  'works': 9551,
#  'start': 8441,
#  'finish': 5085,
#  'worth': 9563,
#  'dollar': 4574,
#  'minute': 6587,
#  'stack': 8418,
#  'Sake': 2167,
#  'Yamazaki': 2866,
#  'straight': 8505,
#  'Tokyo': 2587,
#  'eyes': 4930,
#  'fights': 5061,
#  'power': 7299,
#  'grinds': 5473,
#  'day': 4351,
#  'night': 6816,
#  'Monday': 1686,
#  'Friday': 971,
#  'Works': 2842,
#  'Sunday': 2474,
#  'slang': 8197,
#  'smart': 8235,
#  'crave': 4198,
#  'material': 6470,
#  'things': 8849,
#  'pushing': 7434,
#  'sweats': 8668,
#  'sleepless': 8209,
#  'nights': 6820,
#  'loves': 6353,
#  'grind': 5471,
#  'Yeah': 2873,
#  'Stacking': 2414,
#  'paper': 7016,
#  'gonna': 5411,
#  'always': 3060,
#  'Come': 543,
#  'hello': 5636,
#  'hold': 5683,
#  'Go': 1038,
#  'lean': 6165,
#  'guess': 5497,
#  'kind': 6056,
#  'shy': 8110,
#  'Someone': 2362,
#  'writes': 9581,
#  'maybe': 6484,
#  'Maybe': 1612,
#  'sing': 8146,
#  'song': 8319,
#  'mmm': 6618,
#  'bout': 3563,
#  'fun': 5290,
#  'dial': 4481,
#  'chorus': 3903,
#  '6325792number': 58,
#  '6325792mmm': 57,
#  '6325792': 54,
#  '6325792he': 56,
#  'call': 3700,
#  'anytime': 3109,
#  'verse': 9227,
#  'talked': 8724,
#  'songs': 8320,
#  'Theres': 2544,
#  'wrong': 9584,
#  'calling': 3703,
#  'quite': 7482,
#  'play': 7208,
#  'getting': 5345,
#  'late': 6139,
#  'wait': 9313,
#  'sleep': 8207,
#  'dreaming': 4631,
#  'hook': 5720,
#  'Dream': 738,
#  'lullaby': 6372,
#  'Underneath': 2673,
#  'cherry': 3869,
#  'tree': 9025,
#  'softly': 8286,
#  'passes': 7056,
#  'carries': 3761,
#  'away': 3218,
#  'High': 1164,
#  'sky': 8192,
#  'going': 5402,
#  '6325792sing': 61,
#  'lalaby': 6121,
#  '6325792I': 55,
#  '6325792oooohhhh': 60,
#  '6325792yeahh': 62,
#  '6325792you': 63,
#  '6325792ooohh': 59,
#  'hi': 5656,
#  'Shoulders': 2276,
#  'sideways': 8119,
#  'smack': 8232,
#  'Legs': 1455,
#  'movin': 6689,
#  'Smack': 2335,
#  'Wave': 2760,
#  'hands': 5550,
#  'Clap': 523,
#  'clap': 3927,
#  'care': 3750,
#  'Foot': 941,
#  'foot': 5185,
#  'Hold': 1175,
#  'spinin': 8382,
#  'Flexin': 922,
#  'stand': 8429,
#  'spinnin': 8383,
#  'Spinin': 2396,
#  'tippin': 8928,
#  'Spinnin': 2398,
#  'Drank': 734,
#  'alcohol': 3031,
#  'drop': 4656,
#  'Never': 1746,
#  'thinkin': 8851,
#  'Man': 1583,
#  'rollin': 7779,
#  'dice': 4485,
#  'Seven': 2240,
#  'eleven': 4749,
#  'seven': 8004,
#  'twice': 9102,
#  'Girl': 1024,
#  'tryna': 9073,
#  'kick': 6038,
#  'feet': 5030,
#  'swear': 8664,
#  'wanna': 9335,
#  'spin': 8380,
#  'Ooh': 1843,
#  'freaky': 5245,
#  'deaky': 4365,
#  'switchy': 8691,
#  'pink': 7180,
#  'bikini': 3420,
#  'Rock': 2114,
#  'booty': 3533,
#  'Sweatin': 2487,
#  'blow': 3489,
#  'dress': 4635,
#  'trick': 9032,
#  'Mad': 1559,
#  'fresh': 5253,
#  'Fresher': 970,
#  'fresher': 5254,
#  'groovy': 5480,
#  'dye': 4694,
#  'dashiki': 4340,
#  'Nefertiti': 1741,
#  'edges': 4732,
#  'kinky': 6064,
#  'Mustard': 1715,
#  'beat': 3327,
#  'Like': 1489,
#  'woman': 9527,
#  'find': 5075,
#  'hard': 5565,
#  'dreams': 4632,
#  'Get': 1011,
#  'emotional': 4762,
#  'control': 4111,
#  'deep': 4386,
#  'everything': 4876,
#  'seems': 7960,
#  'loving': 6358,
#  'Woman': 2827,
#  'hooked': 5721,
#  'venom': 9220,
#  'Cant': 439,
#  'seek': 7956,
#  'step': 8465,
#  'ahead': 3002,
#  'Youre': 2895,
#  'two': 9110,
#  'steps': 8470,
#  'real': 7551,
#  'strong': 8536,
#  'lead': 6157,
#  'Seems': 2215,
#  'Without': 2822,
#  'Stop': 2442,
#  'Think': 2552,
#  'mirror': 6591,
#  'open': 6931,
#  'pain': 6996,
#  'erased': 4826,
#  'clearer': 3936,
#  'sun': 8606,
#  'fearless': 5015,
#  'protected': 7389,
#  'believed': 3374,
#  'hearts': 5616,
#  'bleed': 3462,
#  'Inside': 1260,
#  'afraid': 2988,
#  'precious': 7316,
#  'hours': 5754,
#  'Greet': 1070,
#  'dawn': 4350,
#  'arms': 3148,
#  'tomorrow': 8950,
#  'theres': 8836,
#  'meant': 6492,
#  'still': 8476,
#  'moment': 6636,
#  'Fear': 885,
#  'gone': 5409,
#  'lives': 6283,
#  'found': 5221,
#  'ending': 4783,
#  'sweet': 8671,
#  'Aint': 124,
#  'picture': 7162,
#  'hangin': 5552,
#  'wall': 9326,
#  'name': 6753,
#  'realize': 7557,
#  'frame': 5234,
#  'read': 7546,
#  'letters': 6205,
#  'youre': 9639,
#  'near': 6771,
#  'move': 6682,
#  'groove': 5478,
#  'hear': 5606,
#  'voice': 9283,
#  'whispering': 9458,
#  'ear': 4709,
#  'game': 5310,
#  'fantasy': 4986,
#  'pretend': 7336,
#  'reality': 7556,
#  'shelter': 8049,
#  'comfort': 4016,
#  'sound': 8335,
#  'touch': 8975,
#  'half': 5537,
#  'better': 3404,
#  'together': 8943,
#  'memories': 6516,
#  'hanging': 5553,
#  'glad': 5371,
#  'heard': 5607,
#  'Church': 515,
#  'bells': 3381,
#  'ringing': 7739,
#  'choir': 3895,
#  'singing': 8148,
#  'saw': 7894,
#  'Walk': 2742,
#  'aisle': 3022,
#  'finger': 5082,
#  'placed': 7193,
#  'ring': 7738,
#  'Oooh': 1847,
#  'Holding': 1177,
#  'Standing': 2418,
#  'Til': 2571,
#  'death': 4371,
#  'Us': 2686,
#  'part': 7033,
#  'word': 9545,
#  'cry': 4256,
#  'Losing': 1525,
#  'wedding': 9403,
#  'Rice': 2083,
#  'rice': 7714,
#  'Thrown': 2567,
#  'heads': 5600,
#  'begun': 3365,
#  'mine': 6580,
#  'losing': 6331,
#  'Found': 953,
#  'truth': 9067,
#  'beneath': 3386,
#  'lies': 6227,
#  'hide': 5658,
#  'True': 2621,
#  'trade': 8996,
#  'broken': 3614,
#  'wings': 9500,
#  'Trade': 2608,
#  'seen': 7961,
#  'scars': 7905,
#  'kissed': 6066,
#  'crime': 4231,
#  'Seen': 2216,
#  'many': 6438,
#  'people': 7106,
#  'Theyre': 2547,
#  'ya': 9593,
#  'Kiss': 1391,
#  'rub': 7807,
#  'Give': 1027,
#  'prove': 7394,
#  'kiss': 6065,
#  'long': 6309,
#  'Sweet': 2488,
#  'remember': 7643,
#  'stronger': 8537,
#  'pride': 7344,
#  'Beyond': 291,
#  'darkness': 4336,
#  'light': 6240,
#  'Baptize': 245,
#  'tears': 8767,
#  'dry': 4673,
#  'greatest': 5461,
#  'weapon': 9392,
#  'win': 9492,
#  'caused': 3788,
#  'imperfections': 5850,
#  'pure': 7427,
#  'chip': 3887,
#  'threatened': 8870,
#  'breathes': 3596,
#  'salvation': 7865,
#  'tear': 8764,
#  'came': 3711,
#  'redemption': 7592,
#  'torturer': 8972,
#  'became': 3335,
#  'remedy': 7641,
#  'missed': 6601,
#  'Long': 1513,
#  'king': 6061,
#  'King': 1389,
#  'Top': 2597,
#  'Mind': 1660,
#  'body': 3504,
#  'soul': 8333,
#  'Body': 331,
#  'shine': 8055,
#  'bling': 3476,
#  'Calling': 429,
#  'shots': 8088,
#  'head': 5595,
#  'Shine': 2262,
#  'line': 6260,
#  'Try': 2629,
#  'Royalty': 2134,
#  'Bubble': 392,
#  'grow': 5485,
#  'Every': 839,
#  'ruler': 7818,
#  'Everybody': 840,
#  'dey': 4478,
#  'conquer': 4097,
#  'rule': 7817,
#  'longer': 6312,
#  'Remember': 2066,
#  'ooh': 6918,
#  'Real': 2047,
#  'bread': 3585,
#  'Already': 143,
#  'Diamonds': 684,
#  'fist': 5097,
#  'demons': 4423,
#  'rest': 7685,
#  'take': 8714,
#  'Woke': 2826,
#  'foreign': 5193,
#  'slow': 8224,
#  'moving': 6690,
#  'fast': 4994,
#  'Need': 1739,
#  'Take': 2502,
#  'Tryna': 2632,
#  'Ah': 114,
#  'Show': 2281,
#  'BEYONCÉ': 216,
#  'Ven': 2703,
#  'quédate': 7491,
#  'conmigo': 4085,
#  'Dame': 628,
#  'el': 4742,
#  'corazón': 4137,
#  'Vida': 2714,
#  'mía': 6737,
#  'estoy': 4854,
#  'muriendo': 6712,
#  'lento': 6192,
#  'en': 4773,
#  'mi': 6548,
#  'prisión': 7355,
#  'ALEJANDRO': 84,
#  'Anda': 157,
#  'dime': 4504,
#  'lo': 6293,
#  'que': 7455,
#  'sientes': 8123,
#  'quitate': 7481,
#  'pudor': 7406,
#  'deja': 4399,
#  'de': 4361,
#  'sufrir': 8591,
#  'escapa': 4833,
#  'con': 4058,
#  'amor': 3081,
#  'después': 4456,
#  'te': 8757,
#  'llevaré': 6288,
#  'hasta': 5574,
#  'donde': 4584,
#  'quieras': 7472,
#  'temor': 8784,
#  'fronteras': 5265,
#  'sale': 7857,
#  'sol': 8289,
#  'Contigo': 561,
#  'soy': 8345,
#  'capaz': 3736,
#  'sea': 7930,
#  'importa': 5853,
#  'venga': 9218,
#  'porque': 7270,
#  'sé': 8702,
#  'voy': 9297,
#  'Soy': 2385,
#  'tu': 9079,
#  'gitano': 5365,
#  'peregrino': 7112,
#  'la': 6102,
#  'única': 9689,
#  'llave': 6286,
#  'destino': 4459,
#  'cuida': 4276,
#  'más': 6733,
#  'su': 8565,
#  'vida': 9247,
#  'ladrón': 6114,
#  'gitana': 5364,
#  'compañera': 4038,
#  'sigue': 8131,
#  'espera': 4843,
#  'quererte': 7463,
#  'aunque': 3202,
#  'saquen': 7878,
#  'nos': 6837,
#  'cueste': 4271,
#  'duela': 4683,
#  'Esta': 827,
#  'guerra': 5496,
#  'ganado': 5312,
#  'nuestro': 6855,
#  'nací': 6743,
#  'para': 7018,
#  'tus': 9096,
#  'ojos': 6900,
#  'nadie': 6745,
#  'Siempre': 2294,
#  'estar': 4849,
#  'camino': 3715,
#  'Alma': 139,
#  'alma': 3045,
#  'tempestad': 8787,
#  'Dime': 694,
#  'por': 7267,
#  'ir': 5937,
#  'se': 7929,
#  'BEYONCÈ': 215,
#  '0oh': 2,
#  'Alejandro': 129,
#  'fans': 4981,
#  'uhu': 9124,
#  'destiny': 4460,
#  'future': 5302,
#  'best': 3396,
#  'friend': 5256,
#  'children': 3879,
#  'mother': 6665,
#  'didnt': 4487,
#  'even': 4864,
#  ...}

# %%
letras_bow = transform.transform(data['letra']) #transforma o vocabulário em vetor
print(letras_bow)
# Out:
#   (0, 1)	1
#   (0, 53)	1
#   (0, 288)	2
#   (0, 509)	1
#   (0, 511)	2
#   (0, 600)	1
#   (0, 618)	1
#   (0, 715)	1
#   (0, 836)	1
#   (0, 861)	1
#   (0, 1178)	1
#   (0, 1233)	1
#   (0, 1239)	2
#   (0, 1242)	4
#   (0, 1278)	1
#   (0, 1311)	4
#   (0, 1468)	1
#   (0, 1515)	1
#   (0, 1586)	1
#   (0, 1771)	1
#   (0, 1812)	1
#   (0, 1839)	1
#   (0, 2008)	1
#   (0, 2260)	1
#   (0, 2366)	1
#   :	:
#   (517, 8779)	1
#   (517, 8823)	1
#   (517, 8848)	1
#   (517, 8849)	2
#   (517, 8890)	1
#   (517, 8896)	1
#   (517, 8915)	21
#   (517, 8918)	1
#   (517, 8960)	1
#   (517, 9190)	3
#   (517, 9314)	1
#   (517, 9335)	1
#   (517, 9394)	1
#   (517, 9419)	1
#   (517, 9421)	1
#   (517, 9513)	1
#   (517, 9527)	1
#   (517, 9552)	1
#   (517, 9556)	1
#   (517, 9567)	1
#   (517, 9613)	1
#   (517, 9615)	12
#   (517, 9616)	1
#   (517, 9636)	1
#   (517, 9637)	11

# %%
#inicializa TfidfTransform, busca palavras mais importantes 
tfidf_transform = TfidfTransformer().fit(letras_bow)
print(tfidf_transform)

letras_tfidf = tfidf_transform.transform(le) 
print(letras_tfidf)
#as palavras com maior valores de idf são mais significantes
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)
#   (0, 9636)	0.033693664733463975
#   (0, 9623)	0.05311124946936393
#   (0, 9594)	0.05311124946936393
#   (0, 9556)	0.06893092773290604
#   (0, 9549)	0.04296667336101367
#   (0, 9547)	0.02612785108342629
#   (0, 9536)	0.06503781128852354
#   (0, 9520)	0.03860200808807347
#   (0, 9462)	0.05311124946936393
#   (0, 9438)	0.047498308710168136
#   (0, 9422)	0.04982788960646506
#   (0, 9394)	0.036272427191776556
#   (0, 9385)	0.015659321304721197
#   (0, 9323)	0.04188536795097235
#   (0, 9188)	0.06853347366158226
#   (0, 9063)	0.061318972865161525
#   (0, 9058)	0.02948383709949129
#   (0, 9042)	0.03930660549265977
#   (0, 9019)	0.07359008952549989
#   (0, 8995)	0.040078404625648816
#   (0, 8942)	0.05311124946936393
#   (0, 8937)	0.035318648225174595
#   (0, 8915)	0.044382711661267116
#   (0, 8914)	0.05311124946936393
#   (0, 8913)	0.20442223643351404
#   :	:
#   (517, 3218)	0.01090897082147101
#   (517, 3112)	0.018293714177332596
#   (517, 3096)	0.013882579049980387
#   (517, 3060)	0.012455894213304853
#   (517, 3002)	0.02480776191786481
#   (517, 2919)	0.05767268268853953
#   (517, 2918)	0.028836341344269763
#   (517, 2825)	0.028836341344269763
#   (517, 2639)	0.028836341344269763
#   (517, 2576)	0.02705366654922016
#   (517, 2188)	0.20185438940988834
#   (517, 2097)	0.09875667214743251
#   (517, 2076)	0.028836341344269763
#   (517, 2068)	0.028836341344269763
#   (517, 1786)	0.0393876665428699
#   (517, 1629)	0.02480776191786481
#   (517, 1515)	0.017393311577231074
#   (517, 1483)	0.0652807776807596
#   (517, 1448)	0.028836341344269763
#   (517, 1242)	0.011419426143039138
#   (517, 1195)	0.028836341344269763
#   (517, 688)	0.020280919664861695
#   (517, 145)	0.02705366654922016
#   (517, 70)	0.024006163858275222
#   (517, 12)	0.025788838653324823

# %%
nv = MultinomialNB() #inicializa o classificador
nv.fit(letras_tfidf,data['artista']) #treino
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
prev = nv.predict(letra_tfidf)
print (prev)
# Out:
# ['Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Rihanna' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé' 'Beyoncé'
#  'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Beyoncé' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Rihanna'
#  'Beyoncé' 'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Beyoncé' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna' 'Rihanna'
#  'Rihanna' 'Rihanna' 'Rihanna' 'Beyoncé' 'Rihanna' 'Beyoncé' 'Rihanna']

# %%
print("Accurancy: {0:.4f}%".format(accuracy_score(data['artista'],prev)*100),"dos dados de teste estão corretos.")
# Out:
# Accurancy: 96.1390% dos dados de teste estão corretos.
